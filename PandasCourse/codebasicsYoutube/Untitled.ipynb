# %%
import pandas as pd
import numpy as np

# %%
df1= pd.DataFrame({'a':val1,'b':np.arange(1,9)})
df2= pd.DataFrame({'a':val1,'b':np.arange(3,11)})

# %%
val1= np.arange(2,10)
val1
# Out:
# array([2, 3, 4, 5, 6, 7, 8, 9])

# %%
df3=pd.concat([df1,df2])

# %%
df3
# Out:
#    a   b
# 0  2   1
# 1  3   2
# 2  4   3
# 3  5   4
# 4  6   5
# 5  7   6
# 6  8   7
# 7  9   8
# 0  2   3
# 1  3   4
# 2  4   5
# 3  5   6
# 4  6   7
# 5  7   8
# 6  8   9
# 7  9  10

# %%
del df1

# %%
del df2

# %%
df3
# Out:
#    a   b
# 0  2   1
# 1  3   2
# 2  4   3
# 3  5   4
# 4  6   5
# 5  7   6
# 6  8   7
# 7  9   8
# 0  2   3
# 1  3   4
# 2  4   5
# 3  5   6
# 4  6   7
# 5  7   8
# 6  8   9
# 7  9  10
