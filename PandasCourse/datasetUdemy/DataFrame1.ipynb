# %%
import pandas as pd

# %%
nba= pd.read_csv("nba.csv")

# %%
nba.head(1)
nba.tail(5)
nba.index
nba.values
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
rev= pd.read_csv("revenue.csv",index_col='Date')
rev
# print(rev.sum(axis="index"))
# rev.sum(axis=0)
# rev.sum(axis="columns")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.dtypes
nba.dtypes
# nba.get_dtype_counts()
# Out:
# Dorell Wright      1
# Omer Asik          1
# Markieff Morris    1
# Clint Capela       1
# Ty Lawson          1
#                   ..
# JaKarr Sampson     1
# Dahntay Jones      1
# Kevin Garnett      1
# Kris Humphries     1
# Markel Brown       1
# Name: Name, Length: 457, dtype: int64

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba[["Name","Team"]]
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
nba
select=["Name","Number","Position"]
nba[select].head(1)
# Out:
# pandas.core.frame.DataFrame

# %%
nba
nba["Sport"]="Basketball"
nba.insert(1, column= "SabbyLeague", value="Sabby")
nba.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-82ac0dce76e9> in <module>
#       1 nba
#       2 nba["Sport"]="Basketball"
# ----> 3 nba.insert(1, column= "SabbyLeague", value="Sabby")
#       4 nba.head(3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3589         self._ensure_valid_index(value)
#    3590         value = self._sanitize_column(column, value, broadcast=False)
# -> 3591         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3592
#    3593     def assign(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# ...

# %%
nba.head(3)
# Out:
#             Name SabbyLeague League            Team  Number Position   Age  \
# 0  Avery Bradley       Sabby  Sabby  Boston Celtics     0.0       PG  25.0
# 1    Jae Crowder       Sabby  Sabby  Boston Celtics    99.0       SF  25.0
# 2   John Holland       Sabby  Sabby  Boston Celtics    30.0       SG  27.0
#
#   Height  Weight            College     Salary       Sport
# 0    6-2   180.0              Texas  7730337.0  Basketball
# 1    6-6   235.0          Marquette  6796117.0  Basketball
# 2    6-5   205.0  Boston University        NaN  Basketball

# %%
nba= nba["Salary"]*100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-9becf59eeffe> in <module>
# ----> 1 nba= nba["Salary"]*100
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.insert(2, "league","sabby's league")

# %%
nba
# Out:
#               Name            Team          league  Number Position   Age  \
# 0    Avery Bradley  Boston Celtics  sabby's league     0.0       PG  25.0
# 1      Jae Crowder  Boston Celtics  sabby's league    99.0       SF  25.0
# 2     John Holland  Boston Celtics  sabby's league    30.0       SG  27.0
# 3      R.J. Hunter  Boston Celtics  sabby's league    28.0       SG  22.0
# 4    Jonas Jerebko  Boston Celtics  sabby's league     8.0       PF  29.0
# ..             ...             ...             ...     ...      ...   ...
# 453   Shelvin Mack       Utah Jazz  sabby's league     8.0       PG  26.0
# 454      Raul Neto       Utah Jazz  sabby's league    25.0       PG  24.0
# 455   Tibor Pleiss       Utah Jazz  sabby's league    21.0        C  26.0
# 456    Jeff Withey       Utah Jazz  sabby's league    24.0        C  26.0
# 457            NaN             NaN  sabby's league     NaN      NaN   NaN
#
#     Height  Weight            College     Salary
# ...

# %%
nba["Team"].value_counts()
output=False

# %%
nba
# output=False
# Out:
#               Name            Team          league  Number Position   Age  \
# 0    Avery Bradley  Boston Celtics  sabby's league     0.0       PG  25.0
# 1      Jae Crowder  Boston Celtics  sabby's league    99.0       SF  25.0
# 2     John Holland  Boston Celtics  sabby's league    30.0       SG  27.0
# 3      R.J. Hunter  Boston Celtics  sabby's league    28.0       SG  22.0
# 4    Jonas Jerebko  Boston Celtics  sabby's league     8.0       PF  29.0
# ..             ...             ...             ...     ...      ...   ...
# 453   Shelvin Mack       Utah Jazz  sabby's league     8.0       PG  26.0
# 454      Raul Neto       Utah Jazz  sabby's league    25.0       PG  24.0
# 455   Tibor Pleiss       Utah Jazz  sabby's league    21.0        C  26.0
# 456    Jeff Withey       Utah Jazz  sabby's league    24.0        C  26.0
# 457            NaN             NaN  sabby's league     NaN      NaN   NaN
#
#     Height  Weight            College     Salary
# ...

# %%
nba.tail()
nba.dropna(how='any',subset=["College",'Salary'])
# Out:
#               Name            Team          league  Number Position   Age  \
# 0    Avery Bradley  Boston Celtics  sabby's league     0.0       PG  25.0
# 1      Jae Crowder  Boston Celtics  sabby's league    99.0       SF  25.0
# 3      R.J. Hunter  Boston Celtics  sabby's league    28.0       SG  22.0
# 6    Jordan Mickey  Boston Celtics  sabby's league    55.0       PF  21.0
# 7     Kelly Olynyk  Boston Celtics  sabby's league    41.0        C  25.0
# ..             ...             ...             ...     ...      ...   ...
# 449    Rodney Hood       Utah Jazz  sabby's league     5.0       SG  23.0
# 451  Chris Johnson       Utah Jazz  sabby's league    23.0       SF  26.0
# 452     Trey Lyles       Utah Jazz  sabby's league    41.0       PF  20.0
# 453   Shelvin Mack       Utah Jazz  sabby's league     8.0       PG  26.0
# 456    Jeff Withey       Utah Jazz  sabby's league    24.0        C  26.0
#
#     Height  Weight        College     Salary
# ...

# %%
nba.dropna(subset=['league'])
# Out:
#               Name            Team          league  Number Position   Age  \
# 0    Avery Bradley  Boston Celtics  sabby's league     0.0       PG  25.0
# 1      Jae Crowder  Boston Celtics  sabby's league    99.0       SF  25.0
# 2     John Holland  Boston Celtics  sabby's league    30.0       SG  27.0
# 3      R.J. Hunter  Boston Celtics  sabby's league    28.0       SG  22.0
# 4    Jonas Jerebko  Boston Celtics  sabby's league     8.0       PF  29.0
# ..             ...             ...             ...     ...      ...   ...
# 453   Shelvin Mack       Utah Jazz  sabby's league     8.0       PG  26.0
# 454      Raul Neto       Utah Jazz  sabby's league    25.0       PG  24.0
# 455   Tibor Pleiss       Utah Jazz  sabby's league    21.0        C  26.0
# 456    Jeff Withey       Utah Jazz  sabby's league    24.0        C  26.0
# 457            NaN             NaN  sabby's league     NaN      NaN   NaN
#
#     Height  Weight            College     Salary
# ...

# %%
nba.fillna(value=0)
# Out:
#               Name            Team          league  Number Position   Age  \
# 0    Avery Bradley  Boston Celtics  sabby's league     0.0       PG  25.0
# 1      Jae Crowder  Boston Celtics  sabby's league    99.0       SF  25.0
# 2     John Holland  Boston Celtics  sabby's league    30.0       SG  27.0
# 3      R.J. Hunter  Boston Celtics  sabby's league    28.0       SG  22.0
# 4    Jonas Jerebko  Boston Celtics  sabby's league     8.0       PF  29.0
# ..             ...             ...             ...     ...      ...   ...
# 453   Shelvin Mack       Utah Jazz  sabby's league     8.0       PG  26.0
# 454      Raul Neto       Utah Jazz  sabby's league    25.0       PG  24.0
# 455   Tibor Pleiss       Utah Jazz  sabby's league    21.0        C  26.0
# 456    Jeff Withey       Utah Jazz  sabby's league    24.0        C  26.0
# 457              0               0  sabby's league     0.0        0   0.0
#
#     Height  Weight            College     Salary
# ...

# %%
nba["Salary"].fillna(0)
nba["Salary"].value_counts()
# Out:
# 947276.0     31
# 845059.0     18
# 525093.0     13
# 981348.0      6
# 1100602.0     5
#              ..
# 1242720.0     1
# 2489530.0     1
# 5103120.0     1
# 9463484.0     1
# 700902.0      1
# Name: Salary, Length: 309, dtype: int64

# %%
nba.dtypes
# nba.info()
# Out:
# Name         object
# Team         object
# league       object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba=nba.dropna()
nba['Number']=nba['Number'].astype('int')
nba['Salary']=nba['Salary'].astype('int')

# %%
nba['Team'].nunique()
# Out:
# 30

# %%
nba= pd.read_csv('nba.csv')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.sort_values(['Name','Team'],ascending=[False,True])
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# ..               ...                     ...     ...      ...   ...    ...
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
nba.info()
nba.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba= nba.dropna(how='any',subset=['Salary'])
nba
# nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %%
nba=pd.read_csv('nba.csv')
nba.dropna(subset=['Salary'],inplace=True)
nba['Salary']=nba['Salary'].astype('int')
nba.dtypes
nba.rank()
nba['nba salary rank']=nba['Salary'].rank(ascending=False).astype('int')
nba.sort_values('nba salary rank').head(10)
nba['salary_updated']= nba['Salary'].astype('float')
nba.info()
nba['Salary'].nunique()
nba.sort_values()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 446 entries, 0 to 456
# Data columns (total 11 columns):
# Name               446 non-null object
# Team               446 non-null object
# Number             446 non-null float64
# Position           446 non-null object
# Age                446 non-null float64
# Height             446 non-null object
# Weight             446 non-null float64
# College            364 non-null object
# Salary             446 non-null int32
# nba salary rank    446 non-null int32
# salary_updated     446 non-null float64
# dtypes: float64(4), int32(2), object(5)
# memory usage: 38.3+ KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-172-44ed59f54cd9> in <module>
#       9 nba.info()
#      10 nba['Salary'].nunique()
# ---> 11 nba.sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'
