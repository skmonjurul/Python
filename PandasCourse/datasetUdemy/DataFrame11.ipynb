# %%
import pandas as pd

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.ix[bond["Actor"] == "Roger Moore",'Director']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:961: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   return getattr(section, self.name)[new_key]
# Film
# A View to a Kill                   John Glen
# For Your Eyes Only                 John Glen
# Live and Let Die                Guy Hamilton
# Moonraker                      Lewis Gilbert
# Octopussy                          John Glen
# ...

# %%
nba= pd.read_csv("nba.csv")
# nba.head()
# nba.index
# nba.axes
# nba.values
# nba.columns
# nba.shape
# nba.dtypes
nba.get_dtype_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: `get_dtype_counts` has been deprecated and will be removed in a future version. For DataFrames use `.dtypes.value_counts()
#   if __name__ == '__main__':
# float64    4
# object     5
# dtype: int64

# %%
rev= pd.read_csv("revenue.csv", index_col='Date')
rev
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
rev.sum(axis=0)
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
nba= pd.read_csv("nba.csv")
nba['Age']= nba['Age']+1
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.tail()
nba.dropna(how='all', inplace=True)
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  21.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  27.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  25.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  27.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  27.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba['Name'].nunique()
# Out:
# 457

# %%
emp= pd.read_csv("employees.csv")

# %%
emp.dtypes
# emp['Start Date']= pd.to_datetime(emp['Start Date'],format= '%m/%d/%y')
emp.info()
# emp[emp['Senior Management']==None]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
emp[emp['Gender']=='Male'][['Gender']].count()
# Out:
# Gender    424
# dtype: int64

# %%
emp.reset_index()
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
emp.drop_duplicates(subset=['Gender'], keep='first')
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2       Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 20       Lois     NaN  4/22/1995         7:18 PM   64714    4.934
#
#    Senior Management       Team
# 0               True  Marketing
# 2              False    Finance
# 20              True      Legal

# %%
emp[['Gender','Start Date']].drop_duplicates(subset=['Gender','Start Date'], keep='first').count()
# Out:
# Gender        847
# Start Date    992
# dtype: int64

# %%
emp.sort_values(by= )
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
bondDf= pd.read_csv("jamesbond.csv")

# %%
bondDf.set_index('Film',inplace=True)

# %%
bondDf.reset_index(drop=False, inplace=True)

# %%
bondDf.set_index('Film', inplace=True)

# %%
# bondDf.loc['Dr. No']
bondDf.loc[["On Her Majesty's Secret Service","Diamonds Are Forever"]]
# Out:
#                                  Year           Actor       Director  \
# Film
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Diamonds Are Forever                  442.5    34.7                5.8

# %%
'Dr' in bondDf.index
# Out:
# False

# %%
bondDf
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bondDf.ix[bondDf['Actor']=='Daniel Craig','Actor']='Sir Daniel Craig'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bondDf.ix[bondDf['Actor'].str.contains('Daniel Craig')]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                    Year             Actor         Director  Box Office  \
# Film
# Casino Royale      2006  Sir Daniel Craig  Martin Campbell       581.5
# Quantum of Solace  2008  Sir Daniel Craig     Marc Forster       514.2
# Skyfall            2012  Sir Daniel Craig       Sam Mendes       943.5
# Spectre            2015  Sir Daniel Craig       Sam Mendes       726.7
#
#                    Budget  Bond Actor Salary
# Film
# Casino Royale       145.3                3.3
# Quantum of Solace   181.4                8.1
# Skyfall             170.2               14.5
# Spectre             206.3                NaN

# %%
bondDf.iloc[:4,]
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7

# %%
bondDf.rename(index={'Dr. No':'Dr. Yes'}, inplace=True)

# %%
bondDf.ix[['Dr. Yes']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#          Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. Yes  1962  Sean Connery  Terence Young       448.8     7.0
#
#          Bond Actor Salary
# Film
# Dr. Yes                0.6

# %%
bondDf.iloc[:5]
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. Yes                1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. Yes                              0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bondDf.drop(labels=['Actor','Director'],axis=1)
# Out:
#                                  Year  Box Office  Budget  Bond Actor Salary
# Film
# Dr. Yes                          1962       448.8     7.0                0.6
# From Russia with Love            1963       543.8    12.6                1.6
# Goldfinger                       1964       820.4    18.6                3.2
# Thunderball                      1965       848.1    41.9                4.7
# Casino Royale                    1967       315.0    85.0                NaN
# You Only Live Twice              1967       514.2    59.9                4.4
# On Her Majesty's Secret Service  1969       291.5    37.3                0.6
# Diamonds Are Forever             1971       442.5    34.7                5.8
# Live and Let Die                 1973       460.3    30.8                NaN
# The Man with the Golden Gun      1974       334.0    27.7                NaN
# The Spy Who Loved Me             1977       533.0    45.1                NaN
# ...

# %%
bondDf.pop('Actor')
# Out:
# Film
# Dr. Yes                                Sean Connery
# From Russia with Love                  Sean Connery
# Goldfinger                             Sean Connery
# Thunderball                            Sean Connery
# Casino Royale                           David Niven
# You Only Live Twice                    Sean Connery
# On Her Majesty's Secret Service      George Lazenby
# Diamonds Are Forever                   Sean Connery
# Live and Let Die                        Roger Moore
# The Man with the Golden Gun             Roger Moore
# The Spy Who Loved Me                    Roger Moore
# Moonraker                               Roger Moore
# For Your Eyes Only                      Roger Moore
# Never Say Never Again                  Sean Connery
# Octopussy                               Roger Moore
# A View to a Kill                        Roger Moore
# The Living Daylights                 Timothy Dalton
# Licence to Kill                      Timothy Dalton
# ...

# %%
bondDf.sample(n=3, axis= 1)
# Out:
#                                  Box Office  Year  Budget
# Film
# Dr. Yes                               448.8  1962     7.0
# From Russia with Love                 543.8  1963    12.6
# Goldfinger                            820.4  1964    18.6
# Thunderball                           848.1  1965    41.9
# Casino Royale                         315.0  1967    85.0
# You Only Live Twice                   514.2  1967    59.9
# On Her Majesty's Secret Service       291.5  1969    37.3
# Diamonds Are Forever                  442.5  1971    34.7
# Live and Let Die                      460.3  1973    30.8
# The Man with the Golden Gun           334.0  1974    27.7
# The Spy Who Loved Me                  533.0  1977    45.1
# Moonraker                             535.0  1979    91.5
# For Your Eyes Only                    449.4  1981    60.2
# Never Say Never Again                 380.0  1983    86.0
# Octopussy                             373.8  1983    53.9
# ...

# %%
bondDf.nsmallest(3,columns='Year')
# Out:
#                        Year       Director  Box Office  Budget  \
# Film
# Dr. Yes                1962  Terence Young       448.8     7.0
# From Russia with Love  1963  Terence Young       543.8    12.6
# Goldfinger             1964   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. Yes                              0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bondDf.nlargest(3,columns='Bond Actor Salary')
# Out:
#                          Year       Director  Box Office  Budget  \
# Film
# Die Another Day          2002   Lee Tamahori       465.4   154.2
# Skyfall                  2012     Sam Mendes       943.5   170.2
# The World Is Not Enough  1999  Michael Apted       439.5   158.3
#
#                          Bond Actor Salary
# Film
# Die Another Day                       17.9
# Skyfall                               14.5
# The World Is Not Enough               13.5

# %%
bondDf
# Out:
#                                  Year            Director  Box Office  Budget  \
# Film
# Dr. Yes                          1962       Terence Young       448.8     7.0
# From Russia with Love            1963       Terence Young       543.8    12.6
# Goldfinger                       1964        Guy Hamilton       820.4    18.6
# Thunderball                      1965       Terence Young       848.1    41.9
# Casino Royale                    1967          Ken Hughes       315.0    85.0
# You Only Live Twice              1967       Lewis Gilbert       514.2    59.9
# On Her Majesty's Secret Service  1969       Peter R. Hunt       291.5    37.3
# Diamonds Are Forever             1971        Guy Hamilton       442.5    34.7
# Live and Let Die                 1973        Guy Hamilton       460.3    30.8
# The Man with the Golden Gun      1974        Guy Hamilton       334.0    27.7
# The Spy Who Loved Me             1977       Lewis Gilbert       533.0    45.1
# ...

# %%
import pandas as pd

# %%
bondDf= pd.read_csv("jamesbond.csv", index_col='Film')

# %%
bondDf.iloc[:10]
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
# Live and Let Die                 1973     Roger Moore   Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# ...

# %%
def good_movie(row):
    return row[0]+100

# %%
bondDf.apply(lambda x: x[0]+100, axis=1)
# Out:
# Film
# Dr. No                             2062
# From Russia with Love              2063
# Goldfinger                         2064
# Thunderball                        2065
# Casino Royale                      2067
# You Only Live Twice                2067
# On Her Majesty's Secret Service    2069
# Diamonds Are Forever               2071
# Live and Let Die                   2073
# The Man with the Golden Gun        2074
# The Spy Who Loved Me               2077
# Moonraker                          2079
# For Your Eyes Only                 2081
# Never Say Never Again              2083
# Octopussy                          2083
# A View to a Kill                   2085
# The Living Daylights               2087
# Licence to Kill                    2089
# GoldenEye                          2095
# Tomorrow Never Dies                2097
# The World Is Not Enough            2099
# Die Another Day                    2102
# Casino Royale                      2106
# ...

# %%
import pandas as pd

# %%
fortune= pd.read_csv("fortune1000.csv")
fortune[:10]
# Out:
#    Rank             Company                  Sector  \
# 0     1             Walmart               Retailing
# 1     2         Exxon Mobil                  Energy
# 2     3               Apple              Technology
# 3     4  Berkshire Hathaway              Financials
# 4     5            McKesson             Health Care
# 5     6  UnitedHealth Group             Health Care
# 6     7          CVS Health    Food and Drug Stores
# 7     8      General Motors  Motor Vehicles & Parts
# 8     9          Ford Motor  Motor Vehicles & Parts
# 9    10                AT&T      Telecommunications
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# ...

# %%
sectors= fortune.groupby("Sector")

# %%
sectors

# %%
sectors.get_group('Retailing').sum()
# Out:
# Rank                                                     35651
# Company      WalmartCostcoHome DepotTargetLowe’sBest BuyTJX...
# Sector       RetailingRetailingRetailingRetailingRetailingR...
# Industry     General MerchandisersSpecialty Retailers: Othe...
# Location     Bentonville, ARIssaquah, WAAtlanta, GAMinneapo...
# Revenue                                                1465076
# Profits                                                  47830
# Employees                                              6227629
# dtype: object

# %%
sectors.sum()
# Out:
#                                Rank  Revenue  Profits  Employees
# Sector
# Aerospace & Defense            8870   357940    28742     968057
# Apparel                        8757    95968     8236     346397
# Business Services             31074   272195    28227    1361050
# Chemicals                     15928   243897    22628     463651
# Energy                        62199  1517809   -73447    1188927
# Engineering & Construction    15147   153983     5304     406708
# Financials                    63566  2217159   260209    3359948
# Food and Drug Stores           6429   483769    16759    1395398
# Food, Beverages & Tobacco     18629   555967    51417    1211632
# Health Care                   31770  1614707   106114    2678289
# Hotels, Resturants & Leisure  14039   169546    20697    2484245
# Household Products            15749   234737    14428     646038
# Industrials                   26988   497581    20764    1545229
# ...

# %%
sectors['Profits'].sum()
# Out:
# Sector
# Aerospace & Defense              28742
# Apparel                           8236
# Business Services                28227
# Chemicals                        22628
# Energy                          -73447
# Engineering & Construction        5304
# Financials                      260209
# Food and Drug Stores             16759
# Food, Beverages & Tobacco        51417
# Health Care                     106114
# Hotels, Resturants & Leisure     20697
# Household Products               14428
# Industrials                      20764
# Materials                         4428
# Media                            24347
# Motor Vehicles & Parts           25898
# Retailing                        47830
# Technology                      180473
# Telecommunications               48637
# Transportation                   44169
# Wholesalers                       8233
# Name: Profits, dtype: int64

# %%
fortune[:5]
listt=['sum','mean']
agg_dict= {'Rank':'min','Revenue':['max','sum'],'Employees':'sum'}

# %%
fortune.groupby('Sector').agg(agg_dict).iloc[:5]
# Out:
#                     Rank Revenue          Employees
#                      min     max      sum       sum
# Sector
# Aerospace & Defense   24   96114   357940    968057
# Apparel               91   30601    95968    346397
# Business Services    144   19330   272195   1361050
# Chemicals             56   48778   243897    463651
# Energy                 2  246204  1517809   1188927

# %%
fortune[:5]
fortune[fortune['Sector']=='Aerospace & Defense']
# Out:
#      Rank                        Company               Sector  \
# 23     24                         Boeing  Aerospace & Defense
# 44     45            United Technologies  Aerospace & Defense
# 59     60                Lockheed Martin  Aerospace & Defense
# 87     88               General Dynamics  Aerospace & Defense
# 117   118               Northrop Grumman  Aerospace & Defense
# 119   120                       Raytheon  Aerospace & Defense
# 208   209                        Textron  Aerospace & Defense
# 244   245             L-3 Communications  Aerospace & Defense
# 281   282            Precision Castparts  Aerospace & Defense
# 377   378  Huntington Ingalls Industries  Aerospace & Defense
# 388   389    Spirit AeroSystems Holdings  Aerospace & Defense
# 489   490               Rockwell Collins  Aerospace & Defense
# 559   560                    Orbital ATK  Aerospace & Defense
# 604   605                  Triumph Group  Aerospace & Defense
# ...

# %%
for i,j in sectors:
#     print(i)
#     print(j)
    newDf= newDf.append(j.nlargest(1, 'Employees'))

# %%
# newDf= pd.DataFrame(columns= fortune.columns)
# newDf.drop(labels='Rank', axis=1)
# Out:
#                  Company                        Sector  \
# 44   United Technologies           Aerospace & Defense
# 447          Hanesbrands                       Apparel
# 198              Aramark             Business Services
# 100               DuPont                     Chemicals
# 1            Exxon Mobil                        Energy
# 155                AECOM    Engineering & Construction
# 3     Berkshire Hathaway                    Financials
# 16                Kroger          Food and Drug Stores
# 43               PepsiCo     Food, Beverages & Tobacco
# 62          HCA Holdings                   Health Care
# 217           Yum Brands  Hotels, Resturants & Leisure
# 33      Procter & Gamble            Household Products
# 10      General Electric                   Industrials
# 125                Alcoa                     Materials
# 52                Disney                         Media
# 7         General Motors        Motor Vehicles & Parts
# ...

# %%
newDf.reset_index(drop= True,inplace=True)

# %%
newDf[:5]
# Out:
#   Rank              Company               Sector  \
# 0   45  United Technologies  Aerospace & Defense
# 1  448          Hanesbrands              Apparel
# 2  199              Aramark    Business Services
# 3  101               DuPont            Chemicals
# 4    2          Exxon Mobil               Energy
#
#                            Industry           Location Revenue Profits  \
# 0             Aerospace and Defense     Farmington, CT   61047    7608
# 1                           Apparel  Winston-Salem, NC    5732     429
# 2  Diversified Outsourcing Services   Philadelphia, PA   14329     236
# 3                         Chemicals     Wilmington, DE   27940    1953
# 4                Petroleum Refining         Irving, TX  246204   16150
#
#   Employees
# 0    197200
# 1     65300
# 2    216500
# 3     52000
# 4     75600

# %%
week1= pd.read_csv("Restaurant - Week 1 Sales.csv")
week2= pd.read_csv("Restaurant - Week 2 Sales.csv")
cust= pd.read_csv("Restaurant - Customers.csv")
food= pd.read_csv("Restaurant - Foods.csv")

# %%
week1[:2]
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
cust[:2]
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer

# %%
custWeek1= pd.merge(cust, week1, how='left', left_on='ID', right_on='Customer ID', suffixes=('_cust', '_week1'), indicator=True)

# %%
custWeek1[:5]
# Out:
#   First Name Last Name  Gender  Company                     Occupation  \
# 0     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2      Roger     Black    Male  Tagfeed              Account Executive
# 3     Steven     Evans    Male     Fatz               Registered Nurse
# 4       Judy  Morrison  Female  Demivee                Legal Assistant
#
#    Customer ID  Food ID     _merge
# 0          NaN      NaN  left_only
# 1          NaN      NaN  left_only
# 2          3.0      2.0       both
# 3          NaN      NaN  left_only
# 4          NaN      NaN  left_only

# %%
# custWeek1.drop(labels='ID', axis=1, inplace=True)

# %%
custWeek1[custWeek1['_merge'].isin(['left_only'])].ix(['Food ID']!=None)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:109: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   new_self = self.__class__(self.name, self.obj)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-dc7d488f9e69> in <module>
# ...

# %%
week2[:2]
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week12= week1.merge(week2, how='inner', on= 'Customer ID', suffixes=('_week1', '_week2'))

# %%
week12[:2]
# Out:
#    Customer ID  Food ID_1  Food ID_2
# 0          537          9          5
# 1          155          9          3

# %%
week1[week1['Customer ID']==537]
# Out:
#    Customer ID  Food ID
# 0          537        9

# %%
week2[week2['Customer ID']==537]
# Out:
#     Customer ID  Food ID
# 42          537        5

# %%
merged= pd.merge(week1, week2, how='outer', left_on='Customer ID', right_on='Customer ID', suffixes=('_week1', '_week2'), indicator=True)

# %%
merged['_merge'].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
week1['Customer ID'].count()
# Out:
# 250

# %%
week2['Customer ID'].count()
# Out:
# 250

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace = True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-01-08 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2020-01-08 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2020-01-08 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
len(df.drop_duplicates(subset='Gender'))
# Out:
# 3

# %%
df.drop_duplicates(subset=['Gender'])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-01-08 10:20:00   61602   11.849
# 937      Aaron     NaN 1986-01-22 2020-01-08 19:39:00   63126   18.424
# 988      Alice  Female 2004-10-05 2020-01-08 09:34:00   47638   11.209
#
#      Senior Management             Team
# 101               True        Marketing
# 937              False  Client Services
# 988              False  Human Resources

# %%
import pandas as pd

# %%
weeklDf= pd.read_csv("customer")
