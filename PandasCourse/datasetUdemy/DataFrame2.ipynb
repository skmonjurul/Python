# %%
import pandas as pd

# %%
empDF=pd.read_csv("employees.csv")
empDF.info()
empDF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ...

# %%
empDF['Start Date']= pd.to_datetime(empDF['Start Date'])
empDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
# First Name                       933 non-null object
# Gender                           855 non-null object
# Start Date                       1000 non-null datetime64[ns]
# Last Login Time                  1000 non-null object
# Salary                           1000 non-null int64
# Bonus %                          1000 non-null float64
# Senior Management                933 non-null object
# Team                             957 non-null object
# (Start Date, Last Login Time)    1000 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(5)
# memory usage: 70.4+ KB

# %%
empDF.info()
# empDF["Last Login Time"]=pd.to_datetime(empDF["Last Login Time"])
# empDF.drop(["(Start Date, Last Login Time)"],axis=1,inplace=True)
empDF.drop(['Team'],axis=1,inplace=True)
empDF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name                       933 non-null object
# Gender                           855 non-null object
# Start Date                       1000 non-null datetime64[ns]
# Last Login Time                  1000 non-null datetime64[ns]
# Salary                           1000 non-null int64
# Bonus %                          1000 non-null float64
# Senior Management                933 non-null object
# (Start Date, Last Login Time)    1000 non-null datetime64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(1), object(3)
# memory usage: 62.6+ KB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-d66cd78da32e> in <module>
#       2 # empDF["Last Login Time"]=pd.to_datetime(empDF["Last Login Time"])
# ...

# %%
empDF=pd.read_csv("employees.csv")
empDF.info()
empDF['Last Login Time']=pd.to_datetime(empDF['Last Login Time'])
empDF['Start Date']=pd.to_datetime(empDF['Start Date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
empDF.info()
empDF['Gender'].nunique()
empDF['Gender']= empDF['Gender'].astype('category')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
empDF.info()
empDF['Senior Management']=empDF['Senior Management'].astype('bool')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: category(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.9+ KB

# %%
empDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
empDF= pd.read_csv("employees.csv",parse_dates=["Start Date","Last Login Time"])
empDF["Gender"]= empDF["Gender"].astype("category")
empDF["Senior Management"]= empDF["Senior Management"].astype("bool")

# %%
empDF.info()
empDF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2019-10-31 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2019-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2019-10-31 13:00:00  138705    9.340
# ...

# %%
mask1= empDF["Gender"]=='Male'
mask2= empDF["Team"]== 'Marketing'
empDF[mask1 & mask2]
# Out:
# First Name           38
# Gender               41
# Start Date           41
# Last Login Time      41
# Salary               41
# Bonus %              41
# Senior Management    41
# Team                 41
# dtype: int64

# %%
empDF1= pd.read_csv("employees.csv",parse_dates=["Start Date","Last Login Time"])
empDF1.info()
empDF1["Gender"]=empDF1["Gender"].astype('category')
empDF1["Senior Management"]=empDF1["Senior Management"].astype('bool')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
empDF1.head(10)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-10-31 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-10-31 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-10-31 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-10-31 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-10-31 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2019-10-31 01:35:00  115163   10.125
# 6       Ruby  Female 1987-08-17 2019-10-31 16:20:00   65476   10.012
# 7        NaN  Female 2015-07-20 2019-10-31 10:43:00   45906   11.598
# 8     Angela  Female 2005-11-22 2019-10-31 06:29:00   95570   18.523
# 9    Frances  Female 2002-08-08 2019-10-31 06:51:00  139852    7.524
#
#    Senior Management                  Team
# 0               True             Marketing
# 1               True                   NaN
# 2              False               Finance
# ...

# %%
cond1=empDF1['Start Date']<'1991-01-01'
cond2=empDF1['Senior Management']==True
empDF1[cond1 | cond2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2019-10-31 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2019-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2019-10-31 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2019-10-31 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2019-10-31 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2019-10-31 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2019-10-31 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2019-10-31 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2019-10-31 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
empDF2= pd.read_csv("employees.csv",parse_dates=["Start Date","Last Login Time"])
empDF2['Gender']= empDF2['Gender'].astype('category')
empDF2['Senior Management']= empDF2['Senior Management'].astype('bool')

# %%
cond1= empDF2['Team'].isnull()
empDF2[cond1]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2019-10-31 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2019-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2019-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2019-10-31 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2019-10-31 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2019-10-31 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2019-10-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2019-10-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2019-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
empDF2.info()
cond2=empDF2['First Name'].isnull()
empDF2[cond2]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 7          NaN  Female 2015-07-20 2019-10-31 10:43:00   45906   11.598
# 23         NaN    Male 2012-06-14 2019-10-31 16:19:00  125792    5.042
# 25         NaN    Male 2012-10-08 2019-10-31 01:12:00   37076   18.576
# 32         NaN    Male 1998-08-21 2019-10-31 14:27:00  122340    6.417
# ...

# %%
empDF2= pd.read_csv("employees.csv",parse_dates=["Start Date","Last Login Time"])
empDF2["Gender"]=empDF2["Gender"].astype("category")
empDF2["Senior Management"]=empDF2["Gender"].astype("bool")

# %%
empDF2.info()
empDF2.head(10)
cond1= empDF2["Salary"].between(90000, 110000)
cond2= empDF2["Start Date"].between("11:00AM","12:00PM")
empDF2[cond1 | cond2]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-10-31 12:42:00   97308    6.945
# 4        Larry    Male 1998-01-24 2019-10-31 16:47:00  101004    1.389
# 8       Angela  Female 2005-11-22 2019-10-31 06:29:00   95570   18.523
# 11       Julie  Female 1997-10-26 2019-10-31 15:19:00  102508   12.637
# ...

# %%
df3= pd.read_csv("employees.csv",parse_dates=["Start Date","Last Login Time"])
df3["Gender"]= df3["Gender"].astype("category")
df3["Senior Management	"]= df3["Senior Management"].astype("bool")
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
# First Name            933 non-null object
# Gender                855 non-null category
# Start Date            1000 non-null datetime64[ns]
# Last Login Time       1000 non-null datetime64[ns]
# Salary                1000 non-null int64
# Bonus %               1000 non-null float64
# Senior Management     933 non-null object
# Team                  957 non-null object
# Senior Management	    1000 non-null bool
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 56.9+ KB

# %%
df3["First Name"].size
# Out:
# 1000
